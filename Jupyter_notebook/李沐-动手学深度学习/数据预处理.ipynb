# %%
import os
os.makedirs(os.path.join('.', 'data'), exist_ok=True)
data_file = os.path.join('.', 'data', 'house_tiny.csv')
with open(data_file, 'w') as f:
    f.write('NumRooms,Alley,Price\n') # 列名
    f.write('NA,Pave,127500\n') # 每行表示一个数据样本
    f.write('2,NA,106000\n')
    f.write('4,NA,178100\n')
    f.write('NA,NA,140000\n')

# %%
# !pip install pandas
import pandas as pd
data = pd.read_csv(data_file)
data
# Out:
# ...
#    NumRooms Alley   Price
# 0       NaN  Pave  127500
# 1       2.0   NaN  106000
# 2       4.0   NaN  178100
# 3       NaN   NaN  140000

# %%
inputs,outputs=data.iloc[:,0:2],data.iloc[:,2] #前两列，与最后一列
inputs=inputs.fillna(inputs.mean(numeric_only=True))
print(inputs)
# Out:
#    NumRooms Alley
# 0       3.0  Pave
# 1       2.0   NaN
# 2       4.0   NaN
# 3       3.0   NaN

# %%
inputs=pd.get_dummies(inputs,dummy_na=True) #将分类变量（文本）转换为数值变量的常用方法，是机器学习数据预处理；
# dummy_na=True 为缺失值（NA）单独创建一列
print(inputs)
# Out:
#    NumRooms  Alley_Pave  Alley_nan
# 0         3           1          0
# 1         2           0          1
# 2         4           0          1
# 3         3           0          1

# %%
inputs=pd.get_dummies(inputs,dummy_na=True,dtype=int)
print(inputs)
# Out:
#    NumRooms  Alley_Pave  Alley_nan
# 0         3           1          0
# 1         2           0          1
# 2         4           0          1
# 3         3           0          1

# %%
import torch
x,y=torch.tensor(inputs.values),torch.tensor(outputs.values) #从数值转化为张量
x,y
# Out:
# (tensor([[3, 1, 0],
#          [2, 0, 1],
#          [4, 0, 1],
#          [3, 0, 1]]),
#  tensor([127500, 106000, 178100, 140000]))
